# %% [markdown]
# # Practice

# %%
import torch
import sys
import numpy as np

np.set_printoptions(threshold=sys.maxsize)
torch.set_printoptions(threshold=sys.maxsize)
print(torch.__version__)
# Out:
# 1.2.0

# %%
true_or_false = torch.Tensor([False, False, True, False, True, True, False, False]).bool()
print(true_or_false)
new_tensor = torch.rand((8, 128))
print(torch.sum(true_or_false))
print(new_tensor.shape[1])
print(torch.zeros([torch.sum(true_or_false), new_tensor.shape[1]]).float().shape)
prac = torch.zeros((8, 1))
prac[true_or_false] = torch.Tensor([[1], [2], [3]])
print(prac)
new_tensor[true_or_false] = torch.zeros([torch.sum(true_or_false), new_tensor.shape[1]]).float()

print(new_tensor)
# Out:
# tensor([False, False,  True, False,  True,  True, False, False])
# tensor(3)
# 128
# torch.Size([3, 128])
# tensor([[0.],
#         [0.],
#         [1.],
#         [0.],
#         [2.],
#         [3.],
#         [0.],
#         [0.]])
# tensor([[0.7431, 0.5098, 0.3666, 0.3486, 0.2021, 0.2972, 0.1585, 0.0516, 0.8020,
#          0.0554, 0.4575, 0.8059, 0.8115, 0.2001, 0.8317, 0.9429, 0.6479, 0.7944,
#          0.9345, 0.3994, 0.6291, 0.3753, 0.2157, 0.1754, 0.8369, 0.2365, 0.3970,
#          0.9271, 0.4570, 0.7772, 0.4597, 0.4301, 0.5756, 0.4016, 0.7760, 0.7736,
#          0.9681, 0.9337, 0.6180, 0.3092, 0.9867, 0.8051, 0.0629, 0.0421, 0.2751,
#          0.0294, 0.0216, 0.9272, 0.4265, 0.6105, 0.4941, 0.0566, 0.8947, 0.9953,
#          0.7543, 0.2967, 0.9007, 0.0790, 0.7303, 0.6084, 0.0979, 0.3642, 0.0442,
#          0.6553, 0.4697, 0.2266, 0.4421, 0.2754, 0.4220, 0.6811, 0.0122, 0.6872,
#          0.6826, 0.2456, 0.2519, 0.7012, 0.0128, 0.7544, 0.1388, 0.7144, 0.8178,
# ...
